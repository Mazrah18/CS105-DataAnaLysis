# %% [markdown]
# # Retrieval Practice and Learning
#
# What is the most effective way to learn a subject? Many students focus exclusively on the _encoding_ process---that is, how to get the knowledge into memory in the first place. For example, taking notes is an activity for encoding knowledge.
#
# _Retrieval_, on the other hand, is the process of reconstructing that knowledge from memory. [Karpicke and Blunt](http://science.sciencemag.org/content/331/6018/772) (2011) demonstrated that _retrieval_ is more effective for learning than activites designed to promote effective encoding. They conducted an experiment in which subjects had to learn about sea otters by reading a passage. Subjects were randomly assigned to one of two conditions: some were instructed to create a [concept map](https://en.wikipedia.org/wiki/Concept_map) as they read the passage, while others were instructed to practice retrieval (i.e., read the passage, recall as much as they could, read the text again, and recall again). The two main measurements they recorded were:
#
# 1. each subject's score on a follow-up learning test one week later
# 2. each subject's _prediction_ of how well they would do on that test
#
# In this lab, you will analyze data from a _replication_ of Karpicke and Blunt's experiment, conducted by Buttrick _et al_.
# - The data file is : data.csv.
# - The codebook (explaining what the variables mean) is : codebook.csv.

# %%
# READ IN THE DATA SET HERE
import pandas as pd

data_df = pd.read_csv('data.csv')
data_df
# Out:
#       ID  Age  Gender   Date.P1   Date.P2  Condition  IC.1  IC.2  Comp.1  \
# 0    KB1   18  Female  11/21/16  11/28/16    Concept     1     1       1
# 1    KB2   18    Male  11/21/16  11/28/16    Concept     1     1       1
# 2    KB3   18    Male  11/21/16  11/28/16    Concept     1     1       1
# 3    KB4   19  Female  11/21/16  11/28/16    Concept     1     1       1
# 4    KB5   19  Female  11/22/16  11/29/16    Concept     1     1       1
# 5    KB6   19    Male  11/22/16  11/29/16    Concept     1     1       1
# 6    KB7   18    Male  11/22/16   12/6/16    Concept     1     1       1
# 7    KB8   20    Male  11/22/16  11/29/16    Concept     1     1       1
# 8    KB9   20    Male  11/22/16  11/28/16    Concept     1     1       1
# 9   KB10   20  Female  11/29/16   12/6/16    Concept     1     1       1
# 10  KB11   21  Female  11/21/16  11/28/16  Retrieval     1     1       1
# 11  KB12   18  Female  11/21/16  11/29/16  Retrieval     1     1       1
# ...

# %%
data_df.head(10)
# Out:
#      ID  Age  Gender   Date.P1   Date.P2 Condition  IC.1  IC.2  Comp.1  \
# 0   KB1   18  Female  11/21/16  11/28/16   Concept     1     1       1
# 1   KB2   18    Male  11/21/16  11/28/16   Concept     1     1       1
# 2   KB3   18    Male  11/21/16  11/28/16   Concept     1     1       1
# 3   KB4   19  Female  11/21/16  11/28/16   Concept     1     1       1
# 4   KB5   19  Female  11/22/16  11/29/16   Concept     1     1       1
# 5   KB6   19    Male  11/22/16  11/29/16   Concept     1     1       1
# 6   KB7   18    Male  11/22/16   12/6/16   Concept     1     1       1
# 7   KB8   20    Male  11/22/16  11/29/16   Concept     1     1       1
# 8   KB9   20    Male  11/22/16  11/28/16   Concept     1     1       1
# 9  KB10   20  Female  11/29/16   12/6/16   Concept     1     1       1
#
#    Comp.2  ...  Scorer.2.2  R2CS.avg  TS.1 Scorer.1.3  TS.2 Scorer.2.3  \
# 0       1  ...         NaN       NaN  0.36         NK  0.42         MS
# ...

# %%
codebook_df = pd.read_csv('codebook.csv')
codebook_df.head(100)
# Out:
#           Name                    Variable full label  \
# 0           ID                         Participant ID
# 1        netID                              UVA netID
# 2      Date.P1                            Date part 1
# 3      Date.P2                            Date part 2
# 4    Condition                     Condition assigned
# 5         IC.1                     Informed consent 1
# 6         IC.2                     Informed consent 2
# 7       Comp.1                         Compensation 1
# 8       Comp.2                         Compensation 2
# 9         PR.1                  Prediction response 1
# 10        PR.2                  Prediction response 2
# 11       MCS.1                 Map completion score 1
# 12    Scorer.1                               Scorer 1
# 13       MCS.2                 Map completion score 2
# 14    Scorer.2                               Scorer 2
# 15     MCS.avg           Map completion score average
# ...

# %% [markdown]
# # Question 1
#
# Which group felt like they learned more: the subjects who made concept maps or the ones who practiced retrieval? (Or are they about the same?) Make an appropriate visualization and explain what you see.
#
# _Hint:_ Use the variable `PR.2`, which contains the participants' predictions of how well they would do on a test one week later.

# %%
# YOUR CODE HERE
df1 = data_df.groupby("Condition")["PR.2"].mean()

# %%
df1.plot.bar()
# Out:
# <Axes: xlabel='Condition'>

# %%
#Method 2: Using pivot_table
import matplotlib.pyplot as plt

pivot_table = pd.pivot_table(data=data_df, values='PR.2', index='Condition', aggfunc='mean')

pivot_table.plot(kind='bar', legend=False, rot=0)
plt.xlabel('Condition')
plt.ylabel('Mean PR.2 Score')
plt.title('Comparison of PR.2 Scores by Condition')
plt.show()

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
# From both the plots above, we can see that the subjects who made concept maps felt like they learned more than the ones who practiced retreival.

# %% [markdown]
# # Question 2
#
# Which group actually did better on the follow-up learning test one week later? Make an appropriate visualization and explain what you see.
#
# _Hint:_ Don't ask which variable you should use. That is for you to figure out. Read the codebook carefully (consulting the [original paper](http://science.sciencemag.org/content/331/6018/772), if necessary), make an informed decision, and explain your choice.

# %%
# YOUR CODE HERE

pivot_table1 = pd.pivot_table(data=data_df, values='TS.avg', index='Condition', aggfunc='mean')

# %%
pivot_table1
# Out:
#              TS.avg
# Condition
# Concept    0.468846
# Retrieval  0.616471

# %%
pivot_table1.plot.bar()
# Out:
# <Axes: xlabel='Condition'>

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
#
# From the visualization above, we can clearly see that the retrival group performed better on the follo up learning test one week later as compared to the concept maps.

# %% [markdown]
# # Question 3
#
# How good were subjects at predicting how well they would do on the follow-up learning test? Calculate a measure of how well subjects predicted their performance and interpret the value in context. (Optionally, you may want to include a visualization as well.)

# %%
# YOUR CODE HERE

# Creating a pivot table to calculate the mean of PR.2 and TS.avg for each condition
pivot_table2 = pd.pivot_table(data=data_df, values=['PR.2', 'TS.avg'], index='Condition', aggfunc='mean')

# Calculate the prediction accuracy as a measure.
pivot_table2['Prediction Accuracy'] = pivot_table2['TS.avg'] / pivot_table2['PR.2']

# %%
pivot_table2.plot.bar()
# Out:
# <Axes: xlabel='Condition'>

# %%
# Plot the prediction accuracy
plt.figure(figsize=(8, 6))
plt.bar(pivot_table2.index, pivot_table2['Prediction Accuracy'], color=['blue', 'green'])
plt.xlabel('Condition')
plt.ylabel('Prediction Accuracy')
plt.title('Prediction Accuracy by Condition')
plt.ylim(0, 2)  
plt.show()

# %% [markdown]
# **YOUR EXPLANATION HERE**
#
#
# From the measure we calculated above(prediction accuracy) and the visualization graph, we can clearly see the performance accuracy of  retrieval based learning was better as compared to concept based .

# %% [markdown]
# # Question 4
#
# This was a completely randomized experiment. This means that the condition that each subject was assigned to should be independent of their gender, age, and any other subject characteristics. Does that seem to be true in this case? Calculate a summary measure and/or make a visualization, and explain what you see.

# %%
print(pd.pivot_table(data=data_df, index='Condition', values='ID', aggfunc='count'))
print(pd.pivot_table(data=data_df, index='Condition', values='ID', aggfunc='count').plot.bar())
# Out:
#            ID
# Condition
# Concept    26
# Retrieval  17
# Axes(0.125,0.11;0.775x0.77)

# %%
# YOUR CODE HERE
age_pivot = pd.pivot_table(data=data_df, values='ID', index='Condition', columns='Age', aggfunc='count', fill_value=0)
gender_pivot = pd.pivot_table(data=data_df, values='ID', index='Condition', columns='Gender', aggfunc='count', fill_value=0)

# %%
age_pivot
# Out:
# Age        17  18  19  20  21  22
# Condition
# Concept     0  11   8   5   2   0
# Retrieval   1   3   6   4   2   1

# %%
gender_pivot
# Out:
# Gender     Female  Male
# Condition
# Concept         9    17
# Retrieval      12     5

# %%
age_pivot.plot.bar()
# Out:
# <Axes: xlabel='Condition'>

# %%
gender_pivot.plot.bar()
# Out:
# <Axes: xlabel='Condition'>

# %% [markdown]
# **YOUR EXPLANATION HERE**
# The age plot shows that there are more young people concentrated in the concept group rather than retrieval group.
#
# Gender based distribution shows that there are very high percentage of males in concept based and more number of females in retrieval based group.

# %% [markdown]
# # Submission Instructions
#
# Once you are finished, follow these steps:
#
# 1. Restart the kernel and re-run this notebook from beginning to end by going to `Kernel > Restart Kernel and Run All Cells`.
# 2. If this process stops halfway through, that means there was an error. Correct the error and repeat Step 1 until the notebook runs from beginning to end.
# 3. Double check that there is a number next to each code cell and that these numbers are in order.
#
# 4. Upload the Notebook (ipynb) to canvas.
